# %%
import pandas as pd

df = pd.read_csv('watch_history_processed.csv')
df
# Out:
#                                                  title  \
# 0    10 PORTFOLIO PROJECTS TO ADD TO YOUR DATA PORT...
# 1    X2 Free Epic Didier Drogba Pack Opening 😨 Any ...
# 2    700 Free Coins Received New Event Rules !! How...
# 3    Jude Bellingham | 'Out Of The Floodlights' | E...
# 4    Road to 1 Billion… Let’s continue breaking rec...
# ..                                                 ...
# 561  Red Light Area of Amsterdam😱Northern Lights of...
# 562  Dhruv Rathee vs Indian News Channels: The Spec...
# 563  Analyzing Indian Politics  Pro Government vs A...
# 564  The Surprising Truth about Opinions  A Unique ...
# 565  Me screen pe aa gay..🔥🫣#vaibhu #youtubeshorts ...
#
#                                         titleUrl  \
# 0    https://www.youtube.com/watch?v=wObV_hwu2QM
# 1    https://www.youtube.com/watch?v=3ljIKfOdoes
# 2    https://www.youtube.com/watch?v=i8bjKsdrPTg
# 3    https://www.youtube.com/watch?v=HF-ZvueXcg8
# 4    https://www.youtube.com/watch?v=nx3HYHcmqjo
# ..                                           ...
# 561  https://www.youtube.com/watch?v=X0D_vzaFbCQ
# 562  https://www.youtube.com/watch?v=gLUkn0n1Lc8
# 563  https://www.youtube.com/watch?v=By8Rcz8CDvA
# 564  https://www.youtube.com/watch?v=ZVe1NAmuN2s
# 565  https://www.youtube.com/watch?v=3oPIUgo9iRs
#
#                                  time      channel_name  \
# 0    2024-09-14 08:57:06.816000+00:00           Mo Chen
# 1    2024-09-14 07:06:36.281000+00:00      Darongaming
# 2    2024-09-14 07:05:18.601000+00:00        WhiteG-99P
# 3    2024-09-13 06:29:50.458000+00:00   Jude Bellingham
# 4    2024-09-13 06:29:28.498000+00:00    UR · Cristiano
# ..                                ...               ...
# 561  2024-05-25 14:48:43.770000+00:00    RealTalk Clips
# 562  2024-05-25 14:37:13.836000+00:00  PodStream Shorts
# 563  2024-05-25 14:37:09.425000+00:00  PodStream Shorts
# 564  2024-05-25 14:36:56.790000+00:00  PodStream Shorts
# 565  2024-05-25 07:27:33.075000+00:00     Vaibhu  Doshi
#
#                                            channel_url        date  year  \
# 0    https://www.youtube.com/channel/UCDybamfye5An6...  2024-09-14  2024
# 1    https://www.youtube.com/channel/UCn8u2a8Cq5INw...  2024-09-14  2024
# 2    https://www.youtube.com/channel/UC08zyEX9amyrn...  2024-09-14  2024
# 3    https://www.youtube.com/channel/UCgC3HxnSnt7hy...  2024-09-13  2024
# 4    https://www.youtube.com/channel/UCtxD0x6AuNNqd...  2024-09-13  2024
# ..                                                 ...         ...   ...
# 561  https://www.youtube.com/channel/UCkOhyFunM8NpD...  2024-05-25  2024
# 562  https://www.youtube.com/channel/UCtnHGO4DSrhOj...  2024-05-25  2024
# 563  https://www.youtube.com/channel/UCtnHGO4DSrhOj...  2024-05-25  2024
# 564  https://www.youtube.com/channel/UCtnHGO4DSrhOj...  2024-05-25  2024
# 565  https://www.youtube.com/channel/UCmGvMZQsYE3W_...  2024-05-25  2024
#
#      month   weekday  day  hour  minute
# 0        9  Saturday   14     8      57
# 1        9  Saturday   14     7       6
# 2        9  Saturday   14     7       5
# 3        9    Friday   13     6      29
# 4        9    Friday   13     6      29
# ..     ...       ...  ...   ...     ...
# 561      5  Saturday   25    14      48
# 562      5  Saturday   25    14      37
# 563      5  Saturday   25    14      37
# 564      5  Saturday   25    14      36
# 565      5  Saturday   25     7      27
#
# [566 rows x 12 columns]

# %%
df.head()
# Out:
#                                                title  \
# 0  10 PORTFOLIO PROJECTS TO ADD TO YOUR DATA PORT...
# 1  X2 Free Epic Didier Drogba Pack Opening 😨 Any ...
# 2  700 Free Coins Received New Event Rules !! How...
# 3  Jude Bellingham | 'Out Of The Floodlights' | E...
# 4  Road to 1 Billion… Let’s continue breaking rec...
#
#                                       titleUrl  \
# 0  https://www.youtube.com/watch?v=wObV_hwu2QM
# 1  https://www.youtube.com/watch?v=3ljIKfOdoes
# 2  https://www.youtube.com/watch?v=i8bjKsdrPTg
# 3  https://www.youtube.com/watch?v=HF-ZvueXcg8
# 4  https://www.youtube.com/watch?v=nx3HYHcmqjo
#
#                                time     channel_name  \
# 0  2024-09-14 08:57:06.816000+00:00          Mo Chen
# 1  2024-09-14 07:06:36.281000+00:00     Darongaming
# 2  2024-09-14 07:05:18.601000+00:00       WhiteG-99P
# 3  2024-09-13 06:29:50.458000+00:00  Jude Bellingham
# 4  2024-09-13 06:29:28.498000+00:00   UR · Cristiano
#
#                                          channel_url        date  year  month  \
# 0  https://www.youtube.com/channel/UCDybamfye5An6...  2024-09-14  2024      9
# 1  https://www.youtube.com/channel/UCn8u2a8Cq5INw...  2024-09-14  2024      9
# 2  https://www.youtube.com/channel/UC08zyEX9amyrn...  2024-09-14  2024      9
# 3  https://www.youtube.com/channel/UCgC3HxnSnt7hy...  2024-09-13  2024      9
# 4  https://www.youtube.com/channel/UCtxD0x6AuNNqd...  2024-09-13  2024      9
#
#     weekday  day  hour  minute
# 0  Saturday   14     8      57
# 1  Saturday   14     7       6
# 2  Saturday   14     7       5
# 3    Friday   13     6      29
# 4    Friday   13     6      29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566 entries, 0 to 565
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         566 non-null    object
#  1   titleUrl      566 non-null    object
#  2   time          566 non-null    object
#  3   channel_name  566 non-null    object
#  4   channel_url   566 non-null    object
#  5   date          566 non-null    object
#  6   year          566 non-null    int64
#  7   month         566 non-null    int64
#  8   weekday       566 non-null    object
#  9   day           566 non-null    int64
#  10  hour          566 non-null    int64
#  11  minute        566 non-null    int64
# dtypes: int64(5), object(7)
# memory usage: 53.2+ KB

# %%
df.describe()
# Out:
#          year       month         day        hour      minute
# count   566.0  566.000000  566.000000  566.000000  566.000000
# mean   2024.0    7.401060   16.637809   12.127208   28.627208
# std       0.0    1.197312    8.641201    5.236502   16.871106
# min    2024.0    5.000000    1.000000    2.000000    0.000000
# 25%    2024.0    7.000000    8.000000    8.000000   14.000000
# 50%    2024.0    7.000000   20.000000   12.000000   27.000000
# 75%    2024.0    8.000000   23.000000   16.000000   44.000000
# max    2024.0    9.000000   31.000000   22.000000   59.000000

# %%
df.describe(include='all')
# Out:
#                                                 title  \
# count                                             566
# unique                                            537
# top     5 MUST-HAVE Starter Farms for Minecraft 1.21!
# freq                                                3
# mean                                              NaN
# std                                               NaN
# min                                               NaN
# 25%                                               NaN
# 50%                                               NaN
# 75%                                               NaN
# max                                               NaN
#
#                                            titleUrl  \
# count                                           566
# unique                                          540
# top     https://www.youtube.com/watch?v=5zy62Vw-ges
# freq                                              3
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#                                     time    channel_name  \
# count                                566             566
# unique                               566             381
# top     2024-09-14 08:57:06.816000+00:00  UR · Cristiano
# freq                                   1              45
# mean                                 NaN             NaN
# std                                  NaN             NaN
# min                                  NaN             NaN
# 25%                                  NaN             NaN
# 50%                                  NaN             NaN
# 75%                                  NaN             NaN
# max                                  NaN             NaN
#
#                                               channel_url        date    year  \
# count                                                 566         566   566.0
# unique                                                381          61     NaN
# top     https://www.youtube.com/channel/UCtxD0x6AuNNqd...  2024-07-22     NaN
# freq                                                   45          41     NaN
# mean                                                  NaN         NaN  2024.0
# std                                                   NaN         NaN     0.0
# min                                                   NaN         NaN  2024.0
# 25%                                                   NaN         NaN  2024.0
# 50%                                                   NaN         NaN  2024.0
# 75%                                                   NaN         NaN  2024.0
# max                                                   NaN         NaN  2024.0
#
#              month   weekday         day        hour      minute
# count   566.000000       566  566.000000  566.000000  566.000000
# unique         NaN         7         NaN         NaN         NaN
# top            NaN  Saturday         NaN         NaN         NaN
# freq           NaN       117         NaN         NaN         NaN
# mean      7.401060       NaN   16.637809   12.127208   28.627208
# std       1.197312       NaN    8.641201    5.236502   16.871106
# min       5.000000       NaN    1.000000    2.000000    0.000000
# 25%       7.000000       NaN    8.000000    8.000000   14.000000
# 50%       7.000000       NaN   20.000000   12.000000   27.000000
# 75%       8.000000       NaN   23.000000   16.000000   44.000000
# max       9.000000       NaN   31.000000   22.000000   59.000000

# %%
print(df.isnull().sum())
# Out:
# title           0
# titleUrl        0
# time            0
# channel_name    0
# channel_url     0
# date            0
# year            0
# month           0
# weekday         0
# day             0
# hour            0
# minute          0
# dtype: int64

# %%
# Daily view patterns
import matplotlib.pyplot as plt
import seaborn as sns

# Plot views by day
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='day', hue='day', palette='viridis', legend=False)
plt.title('Views by Day of the Month')
plt.xticks(rotation=45)
plt.show()

# Plot views by hour
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='hour', hue='hour', palette='viridis', legend=False)
plt.title('Views by Hour of the Day')
plt.xticks(rotation=45)
plt.show()

# %%
# Monthly & Yearly Trends

# Views per month
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='month', hue='month', palette='viridis', legend=False)
plt.title('Views by Month')
plt.xticks(rotation=45)
plt.show()

# Views per year
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='year', hue='year', palette='viridis', legend=False)
plt.title('Views by Year')
plt.xticks(rotation=45)
plt.show()

# %%
# Most Watched Channels

plt.figure(figsize=(12, 6))
top_channels = df['channel_name'].value_counts().head(10)
sns.barplot(x=top_channels.index, hue=top_channels.index, y=top_channels.values, palette='viridis', legend=False)
plt.title('Top 10 Most Watched Channels')
plt.xticks(rotation=45)
plt.show()

# %%
# Most Watched Videos

plt.figure(figsize=(12, 6))
top_videos = df['title'].value_counts().head(10)
sns.barplot(x=top_videos.index, hue=top_videos.index, y=top_videos.values, palette='viridis', legend=False)
plt.title('Top 10 Most Watched Videos')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128170 (\N{FLEXED BICEPS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Total Watch Time per Day

watch_time_per_day = df.groupby('weekday').size().reset_index(name='videos_watched')

weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
watch_time_per_day['weekday'] = pd.Categorical(watch_time_per_day['weekday'], categories=weekday_order, ordered=True)
watch_time_per_day = watch_time_per_day.sort_values('weekday')

plt.figure(figsize=(10, 6))
sns.barplot(x='weekday', y='videos_watched', hue='weekday', data=watch_time_per_day, palette='viridis', legend=False)
plt.title('Videos Watched per Day')
plt.xlabel('Weekday')
plt.ylabel('Number of Videos Watched')
plt.show()

# %%
# Watch Time by Hour

watch_time_by_hour = df.groupby('hour').size().reset_index(name='videos_watched')

plt.figure(figsize=(10, 6))
sns.barplot(x='hour', y='videos_watched', hue='hour', data=watch_time_by_hour, palette='viridis', legend=False)
plt.title('Videos Watched by Hour of the Day')
plt.show()

# %%
weekday_mapping = {'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6}
df['weekday_num'] = df['weekday'].map(weekday_mapping)

correlation_matrix = df[['year', 'month', 'weekday_num', 'day', 'hour', 'minute']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()
